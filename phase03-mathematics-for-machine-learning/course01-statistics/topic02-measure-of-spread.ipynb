# %% [markdown]
# # 📈 Measures of Spread (Dispersion)
#
# Measures of Spread (also called **dispersion**) help us understand **how far data values are spread out** from the center.
# They show how **consistent** or **variable** the data is.
#
# The main measures of spread are:
#
# 1. **Range**
# 2. **Quartile Deviation (QD) / Interquartile Range (IQR)**
# 3. **Mean Deviation**
# 4. **Variance**
# 5. **Standard Deviation (STD)**
#
# ---
#
# ## **1. Range**
#
# The simplest measure of spread.
#
# **Formula:**
# > Range = Maximum value − Minimum value
#
# **Example:**
# Data: 5, 9, 12, 18
# Range = 18 − 5 = **13**
#
# **Use:**
# - Quick estimate of spread
# - Not reliable when outliers exist
#
# ---
#
# ## **2. Interquartile Range (IQR) & Quartile Deviation (QD)**
#
# **IQR** shows the spread of the **middle 50%** of data.
#
# **Formula:**
# > IQR = Q3 − Q1
#
# **Quartile Deviation (QD):**
# > QD = (Q3 − Q1) ÷ 2
#
# **Use:**
# - Best when data has outliers
# - More reliable than range
#
# ---
#
# ## **3. Mean Deviation**
#
# The average of the **absolute deviations** from the mean or median.
#
# **Formula:**
# > Mean Deviation = (Sum of |x − Mean|) ÷ n
#
# **Use:**
# - Gives a more realistic sense of variation than range
# - Still less used compared to SD
#
# ---
#
# ## **4. Variance**
#
# Variance measures the **average squared deviation** from the mean.
#
# **Formula:**
# > Variance = (Sum of (x − Mean)²) ÷ n
#
# **Use:**
# - Fundamental for advanced statistics
# - Used in probability, machine learning, and data analysis
#
# ---
#
# ## **5. Standard Deviation (STD)**
#
# The **square root of variance**.
# It tells how much data deviates from the mean **in the same units as the data**.
#
# **Formula:**
# > STD = √Variance = √((Sum of (x − Mean)²) ÷ n)
#
# **Example:**
# If variance = 25
# STD = √25 = **5**
#
# **Use:**
# - Most important measure of spread
# - Used everywhere in statistics & ML (normal distribution, z-scores, variability)
#
# ---
#
# ## **Summary Table**
#
# | Measure | Meaning | Sensitive to Outliers? | Best Use |
# |--------|---------|-------------------------|----------|
# | **Range** | Max − Min | Yes | Quick overview |
# | **IQR / QD** | Middle 50% spread | No | Skewed data |
# | **Mean Deviation** | Avg. absolute deviation | Yes | Basic understanding |
# | **Variance** | Avg. squared deviation | Yes | Advanced stats, ML |
# | **Standard Deviation** | Square root of variance | Yes | Most widely used |
#
# ---
