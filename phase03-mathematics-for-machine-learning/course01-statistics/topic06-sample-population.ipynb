# %% [markdown]
# # 📊 Sample vs Population
#
# In statistics, it’s important to understand the difference between a **population** and a **sample**.
#
# ---
#
# ## **1. Population**
#
# - A **population** includes **all members of a group** you want to study.
# - Represents the **entire dataset**.
# - Often too large to study directly.
#
# **Examples:**
# - All adults living in a country
# - Every student in a school
# - All transactions in a company for a year
#
# **Key Terms Related to Population:**
# - **Population Mean (μ)**: Average of the entire population
# - **Population Variance (σ²)**: Variance of the entire population
# - **Population Standard Deviation (σ)**: SD of the entire population
#
# ---
#
# ## **2. Sample**
#
# - A **sample** is a **subset of the population**.
# - Used to **estimate population parameters** because studying the entire population is often impractical.
#
# **Examples:**
# - 500 adults surveyed from a country
# - 50 students selected randomly from a school
# - Transactions from the first month to estimate yearly trends
#
# **Key Terms Related to Sample:**
# - **Sample Mean (x̄)**: Average of the sample
# - **Sample Variance (s²)**: Variance of the sample
# - **Sample Standard Deviation (s)**: STD of the sample
#
# ---
#
# ## **3. Comparison Table**
#
# | Feature       | Population             | Sample                        |
# |---------------|-----------------------|-------------------------------|
# | Definition    | Entire group being studied | Subset of the population    |
# | Size          | Usually large (N)      | Usually smaller (n)           |
# | Symbols       | μ, σ², σ               | x̄, s², s                     |
# | Variance Formula | σ² = Σ(xi − μ)² / N  | s² = Σ(xi − x̄)² / (n−1)      |
# | Purpose       | Represents entire population | Estimate population parameters |
# | Data Type     | Complete               | Partial                        |
#
# ---
#
# ## **4. Key Points**
#
# - **Sample** should be **random** and **representative** to get accurate estimates.
# - **Population parameters** are fixed but often unknown.
# - **Sample statistics** are used to **estimate population parameters**.
#
# ---
